# %%
using Distributions
using Plots
using Random
using SpecialFunctions
using LaTeXStrings,StatsBase, BenchmarkTools

# %%
Random.seed!(123) # Setting the seed
# Funciones auxiliares
@inline sample_sign() = [-1,1]|> rand
@inline uniform_sample() = Uniform() |> rand # Funcion para tomar muestras uniformes de [0,1]
@inline coin_flip() = Bernoulli() |> rand
@inline expo_sample() = Exponential() |> rand
# Out:
# expo_sample (generic function with 1 method)

# %% [markdown]
# # Algoritmos blackbox

# %% [markdown]
# ## Desigualdades

# %%
N = Normal()
f(x) = pdf(N,x)
mu = mean(N)
m = mode(N)
M = pdf(N,m)
sigma2 = var(N)

Mminus = 0.25
@assert Mminus <= M

# %%
#cota 1 Algoritmo LC-f-m
function g1(x,) 
    return [1, exp(1 - abs(x-m)*M) ] |> minimum |> p-> p*M
end

#cota 2 Algoritmo LC-f-mu-sigma
function g2(x)
    sigma = √sigma2
    if abs(x - mu) <= (1 + sqrt(3)) * sigma
        return 1/sigma
    elseif (1 + √3) * sigma <= abs(x-mu) <= (√3 + √12)*sigma
        return 1/(abs(x-mu) - sigma*√3)
    elseif abs(x-mu) >= (√3 + √12)*sigma2
        return 1/(sigma2 * √12) * exp(3/2 - (abs(x-mu))/(sigma * √12) )
    end

end

# cota 3 Algoritmo LC-f-mu
function g3(x)
    if abs(x-mu) <= (1 + 1/(ℯ * sqrt(3)))/f(mu)
        return f(mu)*ℯ*sqrt(3)
    elseif (1 + 1/(ℯ * sqrt(3)))/f(mu) <= abs(x-mu) <= 2/f(mu)
        return 1/(abs(x-mu) - 1/f(mu) )
    elseif abs(x-mu) >= 2/f(mu)
        return f(mu)* exp(2 - abs(x-mu)/f(mu) ) 

    end
end

# cota 4 Algoritmo LC-g-m
# Requiere de h tq h(m) = 1 y M_minus < M
function g4(x)
    return [1, exp(1 - abs(x-m)* Mminus)] |> minimum
end

#cota 5 Algoritmo LC-g-mu-sigma 
# Requiere de h ∝ f tal que h(mu) = 1 
g5(x) = [1, exp( 3/2 - abs(x -mu)/(√sigma2 * √12) ) ] |>
        minimum |>
        a -> a * ℯ * √3

# Cota 6 Algoritmo LC-g-m-sigma
# Requiere de h tq h(m) = 1
g6(x) = [1, exp(1 - (abs(x-m)/(√sigma2 * √12) ))] |>
        minimum
# Out:
# g6 (generic function with 1 method)

# %%
plt_log = plot( x-> x|> f |> log,
    xlims=(-6,6),
    lw=2,
    label=L"\log(f)")
plot!(
    [x-> x|> g1 |> log ,
    x-> x|> g2 |> log ,
    x-> x|> g3 |> log ],
    lw = 2,
    label=[L"\log(g_1)" L"\log(g_2)" L"\log(g_3)"]
)
xlabel!(L"x")




plt= plot( x-> x|> f ,
    xlims=(-6,6),
    lw=2,
    label=L"f")
plot!(
    [x-> x|> g1  ,
    x-> x|> g2  ,
    x-> x|> g3 ],
    lw = 2,
    label=[L"g_1" L"g_2" L"g_3"]
)
xlabel!(L"x")

final = plot(plt_log, plt)
#savefig(final, "cotas1.svg")

# %%
# Funcion propocional
h1(x) = f(x)/f(m)
# Out:
# h1 (generic function with 1 method)

# %%
plt = plot( x-> x|> h1,
    xlims=(-10,10),
    lw=2,
    label=L"h_1")
plot!(f,
    lw=2,
    alpha= 0.7,
    style=:dot,
    label=L"f"
)

plot!([x-> x |> g4,
    x -> x |> g6],
    lw=2,
    label=[L"g_4" L"g_6"]
)
xlabel!(L"x")


plt_log = plot( x-> x|> h1|> log,
    xlims=(-10,10),
    lw=2,
    label=L"\log(h_1)")

plot!(x-> x|> f|> log,
    lw=2,
    alpha= 0.7,
    style=:dot,
    label=L"f"
)

plot!([x-> x |> g4 |> log,
    x -> x |> g6|> log],
    lw=2,
    label=[L"\log (g_4)" L"\log (g_6)"]
)
xlabel!(L"x")
final = plot(plt_log,plt,)
#savefig(final, "cotas2.svg")

# %%
h2(x) = f(x)/f(mu)
# Out:
# h2 (generic function with 1 method)

# %%
plt = plot( x-> x|> h2,
    xlims=(-10,10),
    lw=2,
    label=L"h_2")

plot!(x-> x|> f,
    lw=2,
    alpha= 0.7,
    style=:dot,
    label=L"f"
)


plot!([x-> x |> g5],
    lw=2,
    label=L"g_5"
)
xlabel!(L"x")

plt_log = plot( x-> x|> h2|> log,
    xlims=(-10,10),
    lw=2,
    label=L"\log(h_2)"
)

plot!(x-> x|> f|> log,
    lw=2,
    alpha= 0.7,
    style=:dot,
    label=L"f"
)

plot!([x-> x |> g5 |> log],
    lw=2,
    label=L"\log(g_5)"
)


final = plot( plt_log, plt)
#savefig(final, "cotas3.svg")

# %% [markdown]
# ## Algoritmos 1,2,3

# %%
function algorithmfm(pdf, m)
    # Algoritmo 1
    #algorithmLC-f-m
    M = pdf(m)
    accept = false
    rejected_n = 0

    while accept == false
        B = coin_flip()
        U = uniform_sample()
        S = sample_sign()

        if B==1
            V = uniform_sample()
            X = m + (S*V)/M
            if U*M <= pdf(X)
                return X, rejected_n
            else 
                rejected_n += 1
            end

        else
            E = expo_sample()
            X = m + S*((1+E)/M)

            if U*M*exp(-E) <= pdf(X)
                return X, rejected_n
            else
                rejected_n += 1 
            end

        end
    end
    return X, rejected_n
end

function algorithmLCfm2(pdf)
    # f is a decresing log-concave density on [0,inf) with mode f(0)=M=1
    M = pdf(0)
    U1 = Uniform() |> rand
    Z = U1
    accept = false

    while accept == false
        U2 = Uniform() |> rand
        Z = Z * U2
        Y = 1 + log(1/Z)
        U3 = Uniform() |> rand
        global X = U3 * Y
        accept = Z <= pdf(X)
    end
    
    return X
end

function algorithmLCfmusigma2(pdf,sigma2,mu) 
    # Algoritmo 2
    # Algorithm lC-f-mu-sigma version 2
    p1 = 1 + sqrt(3)
    p2 = 1 + log(sqrt(12))
    p3 = 1

    q = p1 + p2 + p3

    sigma = sqrt(sigma2)
    accept = false

    while accept == false
        S = sample_sign()
        U = Uniform() |> rand
        V = Uniform() |> rand

        if V*q <= p1
            W = Uniform() |> rand
            X = mu + S*W*(1+sqrt(3))*sigma
            if U/sigma <= pdf(X)
                return X
            end

        elseif V*q <= p1 + p2 
            W = Uniform() |> rand
            Y = (sqrt(12))^W 
            X = mu + S * sigma * (sqrt(3) + Y)
            if U/(sigma * Y) <= pdf(X)
                return X
            end
        else 
            E = Exponential() |> rand
            X = mu + S * (sqrt(3) + sqrt(12) * (1 + E)) * sigma
            if U * exp(-E)/(sigma * sqrt(12)) <= pdf(X)
                return X
            end
        end
    end

end

function algorithmLCfmu(pdf,mu)
    # Algoritmo 3
    #algorithm LC-f-mu version 1

    Mplus = pdf(mu) * ℯ * √3 
    Mminus = pdf(mu)
    
    p1 = 1 + ℯ * √3
    p2 = 1 + log(√3)
    p3 = 1
    q = p1 + p2 + p3

    accept = false

    while accept == false
        S = [-1,1] |> rand 
        U = uniform_sample()
        V = uniform_sample()


        if V * q <= p1
            W = uniform_sample()
            X = mu + S*(1 + 1/(ℯ * √3))*W*(1/Mminus)

            if U*Mplus <= pdf(X)
                return X
            end
        elseif V*q <= p1 + p2
            W = uniform_sample()
            Y = 1/(Mplus^W * Mminus^(1- W))
            X = mu + S*(1/Mminus + Y )
            if U/Y <= pdf(X)
                return X
            end
        else
            E = expo_sample()
            X = mu + S*(2+ E )/Mminus
            if U*Mminus*exp(-E) <= pdf(X)
                return X
            end
        end
    end
    return X
    
end
# Out:
# algorithmLCfmu (generic function with 1 method)

# %% [markdown]
# Probamos ambos metodos

# %% [markdown]
# ### Prueba de simulacion

# %%
# Setup de prueba
N = Normal(4,1)
f1(x) = pdf(N,x) # pdf de la distribucion Normal
m1 = mode(N)
sigma2 = var(N)
mu = mean(N)

cdf1(x) = cdf(N,x)
# Out:
# cdf1 (generic function with 1 method)

# %%
ecdf1 = [algorithmfm(f1,m1) |> first for _ in 1:1000] |> smpl -> ecdf(smpl)
ecdf2 = [algorithmLCfmusigma2(f1,sigma2,mu) |> first for _ in 1:1000] |> smpl -> ecdf(smpl)
ecdf3 = [algorithmLCfmu(f1,mu) |> first for _ in 1:1000] |> smpl -> ecdf(smpl)

plot(cdf1, lw=3, xlims=(-4,10), label="CDF")
plot!([x-> ecdf1(x) x-> ecdf2(x) x-> ecdf3(x)], lw=3, label=["CDF empirica 1" "CDF empirica 2" "CDF empirica 3"])
title!("Comparaciones muestras")
ylims!(0,1)

# %% [markdown]
# Comparacion con los metodos de muestreo de Distributions.jl

# %%
# Muestreo de una normal usando el algorithmLC-f-m
@benchmark algorithmfm($f1,$m1)
# Out:
# BenchmarkTools.Trial: 10000 samples with 209 evaluations per sample.
#  Range (min … max):  547.646 ns …  26.301 μs  ┊ GC (min … max): 0.00% … 96.08%
#  Time  (median):     708.933 ns               ┊ GC (median):    0.00%
#  Time  (mean ± σ):   761.788 ns ± 758.817 ns  ┊ GC (mean ± σ):  6.31% ±  6.16%
#
#                      ▁▂▃▅█▆▇▇▆█▇▆▅▅▃▂▁
#   ▁▁▁▁▁▁▁▁▁▂▂▂▂▃▄▄▅▇███████████████████▇▆▆▅▄▃▃▃▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁ ▄
#   548 ns           Histogram: frequency by time          898 ns <
#
#  Memory estimate: 784 bytes, allocs estimate: 35.

# %%
# Muestreo de una normal usando el metodo default
@benchmark rand($N)

# Muestreo de una normal usando el algorithmLC-f-m
@benchmark algorithmfm($f1,$m1)
# Out:
# BenchmarkTools.Trial: 10000 samples with 198 evaluations per sample.
#  Range (min … max):  557.237 ns …  19.043 μs  ┊ GC (min … max): 0.00% … 95.35%
#  Time  (median):     725.586 ns               ┊ GC (median):    0.00%
#  Time  (mean ± σ):   793.837 ns ± 792.707 ns  ┊ GC (mean ± σ):  6.26% ±  6.01%
#
#          ▂▅██▇▅▂
#   ▂▂▂▃▄▅▇████████▆▅▄▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▂▂▂▂▂▂▂▂▂▁▂ ▃
#   557 ns           Histogram: frequency by time          1.5 μs <
#
#  Memory estimate: 770 bytes, allocs estimate: 34.

# %%
sample = [algorithmfm(f,m) for i in 1:1000];

# %%
histogram(sample,normalize=:pdf,label="Muestra",alpha=0.7,color=:pink)
plot!(f,label="pdf",linestyle = :dot, lw=4.0,color=:red)
xlims!(1,maximum(sample))
plot!(legendfontsize=10)
xlabel!("x")
title!("Algoritmo LC-f-m 1")
# Out:
# MethodError: no method matching xlims!(::Int64, ::Tuple{Float64, Int64})
#
# Closest candidates are:
#   xlims!(::Real, ::Real; kw...)
#    @ Plots ~/.julia/packages/Plots/MR7sb/src/shorthands.jl:470
#   xlims!(::Union{Plots.Plot, Plots.Subplot}, ::Tuple{Real, Real}; kw...)
#    @ Plots ~/.julia/packages/Plots/MR7sb/src/shorthands.jl:472
#
#
# Stacktrace:
#  [1] top-level scope
#    @ In[16]:3

# %%
N = Normal(0,1)
f(x) = pdf(N,x)/pdf(N,0)
# Out:
# f (generic function with 1 method)

# %%
sample = [algorithmLCfm2(f) for i in 1:1000];

# %%
histogram(sample,normalize=:pdf,label="Muestra",alpha=0.7,color=:pink)
plot!(f,label="pdf",linestyle = :dot, lw=4.0,color=:red)
xlims!(1,maximum(sample))
plot!(legendfontsize=10)
xlabel!("x")

# %% [markdown]
# ## Algoritmo 4, 6

# %%
function algorithmLCgm(h,m,M_minus)
    # Algoritmo 4
    # Algorithm LC-g-m version 1
    
    accept = false

    while accept == false
        
        B = Bernoulli() |> rand
        S = [1,-1] |> rand
        U = Uniform() |> rand
    
        if B == 1
            V = Uniform() |> rand
            X = m + (S*V)/M_minus
            if U <= h(X)
                return X
            end
        else 
            E = Exponential() |> rand
            X = m + S*(1+E)/M_minus
            if U*exp(-E) <= h(X)
                return X
            end
        end
    end
end

function algorithmLCgmigma(h,m,sigma2)
    # Algoritmo 6
    # Algorithm LC-g-m-σ version 2
    
    @assert h(m) == 1
    accept = false

    while accept == false
        B = Bernoulli() |> rand
        S = [-1,1] |> rand 
        U = Uniform() |> rand

        if B == 1
            V = Uniform() |> rand
            X = m + S*V*sqrt(sigma2)*sqrt(12)
            if U <= h(X)
                return X 
            end 
        else
            E = Exponential() |> rand
            X = m + S*(1+E)*sqrt(sigma2)*sqrt(12)
            if U*exp(-E) <= h(X)
                return X 
            end
        end
    end    
end
# Out:
# algorithmLCgmigma (generic function with 1 method)

# %% [markdown]
# ### Comparacion muestreo

# %%
h1(x) = f1(x)/f1(m1)
Mminus = 0.25
@assert m1 > Mminus

# %%
ecdf4 = [algorithmLCgm(h1, m1, Mminus) |> first for _ in 1:1000] |> smpl -> ecdf(smpl)
ecdf6 = [algorithmLCgmigma(h1,m1,sigma2) |> first for _ in 1:1000] |> smpl -> ecdf(smpl)

plot(cdf1, lw=3, xlims=(-4,10), label="CDF")
plot!([x-> ecdf4(x) x-> ecdf6(x)], lw=3, label=["CDF empirica 4" "CDF empirica 6"])
title!("Comparaciones muestras")
ylims!(0,1)

# %% [markdown]
# ## Algoritmo 5

# %%
function algorithmLCgmusigma(h,mu,sigma2)
    # Algoritmo 5
    #algorithm LC-g-μ-σ version 1
    # Takes h prop to f such that h(mu) = 1
    # mu, sigma2 mean and std of f
    
    @assert h(mu) == 1
    accept = false

    while accept == false
        B = Bernoulli(3/5) |> rand
        S = [-1,1] |> rand 
        U = Uniform() |> rand

        if B == 1
            V = Uniform() |> rand
            X = mu + S*V*sqrt(sigma2)*sqrt(27)
            if U*exp(1)*sqrt(3) <= h(X)
                return X
            end
        else
            E = Exponential() |> rand
            X = mu + S*(1+E)*sqrt(sigma2)*sqrt(12)
            if U*sqrt(3)*exp(1-E) <= h(X)
                return X
            end
        end
    end
    return X
end
# Out:
# algorithmLCgmusigma (generic function with 1 method)

# %% [markdown]
# #### Prueba de meustreo

# %%
h2(x) = f(x)/f(mu)

ecdf5 = [algorithmLCgmusigma(h2,mu,sigma2) for _ in 1:1000] |> smpl -> ecdf(smpl)

plot(cdf1, lw=3, xlims=(-4,10), label="CDF")
plot!([x-> ecdf5(x)], lw=3, label="CDF empirica 5")
title!("Comparaciones muestras")
ylims!(0,1)

# %% [markdown]
# ## Benchmarks
#
# Recordatorio
#
# * Algoritmo 1: LC-f-m version 1
# * Algoritmo 2: lC-f-mu-sigma version 2
# * Algoritmo 3: LC-f-mu version 2
# * Algoritmo 4: LC-g-m version 1
# * Algoritmo 5: LC-g-mu-sigma version 1
# * Algoritmo 6: LC-g-m-sigma version 2

# %%
N = Normal(4,1)
f1(x) = pdf(N,x) # pdf de la distribucion Normal
m1 = mode(N);
mu1 = mean(N)
sigma1 = std(N)
g1(x) = f(x)/f(m1) # g(x) = f(x)/f(m) tal que g(m) = 1

h1(x) = f(x)/f(mu1) #h(x) = f(x)/f(mu) s.a h(mu) = 1


Mminus1 = 0.25 #Constant s.t f(m) >= Mminus
@assert f1(m1) >= Mminus1

# %%
# Muestreo de una normal usando el metodo default
@benchmark rand($N)
# Out:
# BenchmarkTools.Trial: 10000 samples with 1000 evaluations per sample.
#  Range (min … max):  3.583 ns … 28.000 ns  ┊ GC (min … max): 0.00% … 0.00%
#  Time  (median):     4.041 ns              ┊ GC (median):    0.00%
#  Time  (mean ± σ):   4.054 ns ±  0.633 ns  ┊ GC (mean ± σ):  0.00% ± 0.00%
#
#                       ▃  ▆  ▇ █  █  ▇  ▅  ▂
#   ▂▁▂▁▁▂▁▁▃▁▁▄▁▁▆▁▁█▁▁█▁▁█▁▁█▁█▁▁█▁▁█▁▁█▁▁█▁▁█▁▁▆▁▁▅▁▁▄▁▁▃▁▂ ▃
#   3.58 ns        Histogram: frequency by time        4.42 ns <
#
#  Memory estimate: 0 bytes, allocs estimate: 0.

# %%
@benchmark algorithmfm($f1,$m1) #Algoritmo 1
# Out:
# BenchmarkTools.Trial: 10000 samples with 189 evaluations per sample.
#  Range (min … max):  550.704 ns …  15.599 μs  ┊ GC (min … max): 0.00% … 94.45%
#  Time  (median):     710.101 ns               ┊ GC (median):    0.00%
#  Time  (mean ± σ):   767.372 ns ± 836.553 ns  ┊ GC (mean ± σ):  6.88% ±  5.98%
#
#                      ▂▃▄▅▅▆▇█▇███▇▆▄▄▄▃▁▁
#   ▂▁▁▂▂▂▂▂▂▃▃▃▄▄▄▅▇▇██████████████████████▇▆▆▅▅▄▃▃▃▃▃▃▂▃▃▂▂▂▂▂▂ ▅
#   551 ns           Histogram: frequency by time          887 ns <
#
#  Memory estimate: 788 bytes, allocs estimate: 35.

# %%
# Muestreo de una normal usando el algorithmLC-f-sigma2-mu
@benchmark algorithmLCfmusigma2($f1,$sigma2,$mu) #Algoritmo 2
# Out:
# BenchmarkTools.Trial: 10000 samples with 174 evaluations per sample.
#  Range (min … max):  822.316 ns … 31.818 μs  ┊ GC (min … max): 0.00% … 95.49%
#  Time  (median):       1.081 μs              ┊ GC (median):    0.00%
#  Time  (mean ± σ):     1.164 μs ±  1.060 μs  ┊ GC (mean ± σ):  6.66% ±  6.86%
#
#                     ▁▂▄▄▅▅▇▇▆▆█▆▆▆▅▄▂▂▁
#   ▁▁▁▁▁▁▁▂▂▃▃▃▄▅▅▆▇████████████████████▇█▇▅▅▄▄▃▃▃▂▂▂▂▂▁▁▁▁▁▁▁▁ ▄
#   822 ns          Histogram: frequency by time         1.38 μs <
#
#  Memory estimate: 1.13 KiB, allocs estimate: 36.

# %%
@benchmark algorithmLCfmu($f1,$mu) #Algoritmo 3
# Out:
# BenchmarkTools.Trial: 10000 samples with 10 evaluations per sample.
#  Range (min … max):  870.800 ns … 244.292 μs  ┊ GC (min … max): 0.00% … 97.22%
#  Time  (median):       2.921 μs               ┊ GC (median):    0.00%
#  Time  (mean ± σ):     3.229 μs ±   7.124 μs  ┊ GC (mean ± σ):  6.47% ±  2.92%
#
#                 ▁▂▂▄▅▄▅▆▅██▆▇▆▅▅▅▃▃▂▂▁▁▁
#   ▁▁▁▁▂▂▃▃▄▄▅▆██████████████████████████▇▇▇▆▅▅▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▁▁ ▅
#   871 ns           Histogram: frequency by time         5.62 μs <
#
#  Memory estimate: 1.10 KiB, allocs estimate: 53.

# %%
@benchmark algorithmLCgm($g1,$m1,$Mminus1) #Algoritmo 4
# Out:
# BenchmarkTools.Trial: 10000 samples with 10 evaluations per sample.
#  Range (min … max):  500.000 ns … 247.129 μs  ┊ GC (min … max): 0.00% … 97.64%
#  Time  (median):       1.529 μs               ┊ GC (median):    0.00%
#  Time  (mean ± σ):     1.660 μs ±   4.228 μs  ┊ GC (mean ± σ):  4.33% ±  1.70%
#
#               ▁▁▂▄▃▅▆▆▆██▆▇█▆▅▄▅▄▄▄▁▃▂▁
#   ▁▁▁▂▂▂▃▄▅▅▇██████████████████████████▇▇▇▆▆▅▄▄▄▄▃▃▃▂▃▂▂▂▂▂▂▂▁▁ ▅
#   500 ns           Histogram: frequency by time         2.97 μs <
#
#  Memory estimate: 456 bytes, allocs estimate: 20.

# %%
@benchmark algorithmLCgmusigma($h1,$mu1,$sigma1) #Algoritmo 5
# Out:
# BenchmarkTools.Trial: 10000 samples with 6 evaluations per sample.
#  Range (min … max):  1.174 μs … 411.965 μs  ┊ GC (min … max): 0.00% … 96.69%
#  Time  (median):     7.465 μs               ┊ GC (median):    0.00%
#  Time  (mean ± σ):   8.275 μs ±  12.821 μs  ┊ GC (mean ± σ):  4.68% ±  3.05%
#
#              ▁▃▃▄▅▅▅▆▅▄█▅▆▄▄▅▄▅▃▃▁▁
#   ▁▁▁▂▂▃▄▅▆▆█████████████████████████▇▇▆▅▅▄▄▄▄▄▃▃▃▃▃▃▂▂▂▂▂▂▂▂ ▄
#   1.17 μs         Histogram: frequency by time        16.9 μs <
#
#  Memory estimate: 1.12 KiB, allocs estimate: 54.

# %%
@benchmark algorithmLCgmigma($g1,$m1,$sigma1) #Algoritmo 6
# Out:
# BenchmarkTools.Trial: 10000 samples with 151 evaluations per sample.
#  Range (min … max):  1.214 μs … 18.510 μs  ┊ GC (min … max): 0.00% … 90.62%
#  Time  (median):     1.538 μs              ┊ GC (median):    0.00%
#  Time  (mean ± σ):   1.615 μs ±  1.066 μs  ┊ GC (mean ± σ):  4.50% ±  6.20%
#
#                      ▁▂▃▅▅▆▆▇█▇███▇▇▆▆▄▄▄▂▂
#   ▂▂▁▂▂▂▂▂▃▃▃▃▄▄▅▆▆▇█████████████████████████▇▇▆▅▅▄▄▄▃▃▃▃▂▂▂ ▅
#   1.21 μs        Histogram: frequency by time        1.83 μs <
#
#  Memory estimate: 1.09 KiB, allocs estimate: 53.
