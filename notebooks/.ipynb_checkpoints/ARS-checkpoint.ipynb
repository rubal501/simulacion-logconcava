# %%
using Plots, Distributions

# %% [markdown]
# ## Prueba de concepto de los envelopes

# %%
sigma2 = 1
mu = 0

K = 1/( sqrt( 2 * pi * sigma2)  )
f(x)= exp(- (x - mu)^2/(2 * sigma2) ) #Densidad no normalizada
fnorm(x) = f(x)*K
h(x)= log( f(x)) # Log densidad 
hprime(x) = - (x - mu)/sigma2  # Derivada log densidad
# Out:
# hprime (generic function with 1 method)

# %%
T = [-1., 0.1, 1.5] # absicsa
T = sort(T)
k = length(T)
# Out:
# 3

# %%
# Para las tangentes
a = [ hprime(xk) for xk in T] # Pendiente de las tangentes 
b = [ h(T[k]) - a[k]*T[k] for k in 1:length(T) ] # Sesgo de las tangentes 
z = [ (b[k+1] - b[k])/(a[k] - a[k+1]) for k in 1:length(T)-1  ] |> #interseccion de tangentes
    A-> append!(A,[Inf,-Inf]) |> 
    sort!;

# Para las secantes
hs = h.(T)
m = [(hs[k+1] - hs[k] )/(T[k+1] - T[k]) for k in 1:length(T)-1  ]
# Out:
# 2-element Vector{Float64}:
#   0.44999999999999996
#  -0.8000000000000002

# %%
function tangent(x,T,Z,A,B)

    i = searchsortedfirst(Z,x) -1 
    return A[i]*x + B[i]
end

function secant(x,H,M,T)
    if x < first(T) || last(T) < x
        return -Inf
    else
        i= searchsortedfirst(T,x)-1
        return H[i] + M[i] * (x - T[i]) 
    end
    
end

lk(x) = secant(x,hs,m,T)

uk(x) =  tangent(x,T,z,a,b)
# Out:
# uk (generic function with 1 method)

# %%
plot(x-> uk(x),
    lw=2,
    style=:dot,
    label="Envolvente")

plot!(x -> h(x),
    lw=2,
    label="Log(f)")

plot!(x -> lk(x),
    lw=2,
    label="lower")

scatter!(T, h.(T),
    label=""
    )

xlims!(-2,2)
ylims!(-3,1)

# %%
#funcion para calcular el area de la i-esima funcion envolvente
function area(i,A,B,Z)
    Li = Z[i]
    Ri = z[i+1]
    if A[i] == 0
        return (Ri - Li)*exp(B[i])
    elseif A[i] != 0
        return (exp(A[i]*Ri) - exp(A[i]*Li) )/A[i] * exp(B[i])
    end
end

function cdfinverse(u,i,A,B,Z)
    Li = Z[i]
    Ri = z[i+1]
    Ai = A[i]

    if A[i] == 0
        return Li + u*(Ri - Li)
    elseif A[i] != 0
        return (1/Ai) * log(u*exp( Ai * Ri) + (1-u)*exp( Ai * Li) )
    end

end


function sample_env(A,B,Z)
    i = Categorical(ps) |> rand
    U = Uniform() |> rand

    return cdfinverse(U,i,A,B,Z)
end

areas = [ area(i,a,b,z) for i in 1:length(T)]
ps = areas ./ sum(areas);

# %%
smpl = [sample_env(a,b,z) for _ in 1:1000];

# %%
histogram(smpl,
    normalize=:pdf,
    label="Muestra de ",
    alpha=0.6)
plot!(x-> exp(uk(x))/sum(areas),
    lw=2,
    style=:dot,
    label="g normalizada")

# %% [markdown]
# ## Implementacion del ARS

# %%
# Helper functions 

function tangent_vectors(h,hprime,X)
    # Calcula los vectores necesarios para las tangentes 
    a = [ hprime(xk) for xk in X] # Pendiente de las tangentes 
    b = [ h(X[k]) - a[k]*X[k] for k in 1:length(X) ] # Sesgo de las tangentes 
    z = [ (b[k+1] - b[k])/(a[k] - a[k+1]) for k in 1:length(X)-1  ] |> #interseccion de tangentes
        A-> append!(A,[Inf,-Inf]) |> 
        sort!;
    return a,b,z
end


function secant_vectors(h,X)
    hs = h.(T)
    m = [(hs[k+1] - hs[k] )/(X[k+1] - X[k]) for k in 1:length(X)-1  ]
    return hs,m
end
# Out:
# secant_vectors (generic function with 1 method)

# %%
function ARS(T,h,hprime,N)
    # T: absisas originales
    
    X = T
    A,B,Z = tangent_vectors(h,hprime,X)
    Hs, M = secant_vectors(h,X)

    smpl = []

    while length(smpl) < N
        accept = false
        x = sample_env(A,B,Z)

        w = Uniform() |> rand

        # squeeze test
        lower = secant(x,Hs,M,X)
        upper =  tangent(x,X,Z,A,B)
        hx = h(x)

        # squeezing
        if w <= exp(lower - upper)
            accept = true
            #append!(smpl,x)
        end

        # rejection test

        if w<= exp(hx - upper)
            accept = true
        end 

        if accept
            append!(smpl,x)
        end

        # Lo agregamos solo si falla el squeezing
        if w <= exp(lower - upper) == false
            append!(X,x) |> sort!
            A,B,Z = tangent_vectors(h,hprime,X)
            Hs, M = secant_vectors(h,X)
        end

    
    end


    return smpl

end
# Out:
# ARS (generic function with 1 method)

# %%
T = [-1., 0.1, 1.5] |> sort # absicsa

tst = ARS(T,h,hprime,1000);

# %%
histogram(tst,
    normalize=:pdf,
    label="Muestra de ",
    alpha=0.6)
plot!(fnorm)

# %% [markdown]
# ## Experimento con forward diff

# %% [markdown]
# ## Benchmarkeo

# %%
using BenchmarkTools

# %%
@benchmark ARS($T,$h,$hprime,1000)
# Out:
# BenchmarkTools.Trial: 8 samples with 1 evaluation per sample.
#  Range (min … max):  548.897 ms … 874.535 ms  ┊ GC (min … max): 5.35% … 10.35%
#  Time  (median):     666.741 ms               ┊ GC (median):    8.49%
#  Time  (mean ± σ):   679.117 ms ± 108.880 ms  ┊ GC (mean ± σ):  8.60% ±  1.77%
#
#   █   █       █    █        █   █            █                █
#   █▁▁▁█▁▁▁▁▁▁▁█▁▁▁▁█▁▁▁▁▁▁▁▁█▁▁▁█▁▁▁▁▁▁▁▁▁▁▁▁█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█ ▁
#   549 ms           Histogram: frequency by time          875 ms <
#
#  Memory estimate: 582.42 MiB, allocs estimate: 32912453.
